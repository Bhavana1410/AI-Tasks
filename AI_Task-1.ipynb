# %% [markdown]
# <h1><b>AI Task-1</h1>
#
# <h3>Battula Bhavana</h3>
# <h3>CH.EN.U4AIE21010</h3>
#
# <hr>

# %% [markdown]
# <h2>Q1</h2>

# %%
import csv
import pandas as pd

def readtxt(textfile) :
  file = open("onelinefile.txt", 'r')
  data = file.read()
  return data
      
def convertcsv(data):
  csvdata = [[]]
  ptr1 = 0   
  ptr2 = 0
  row = []
  for ptr2 in range(len(data)):
      dptr1 = data[ptr1]
      dptr2 = data[ptr2]
      try:  dptr1 = int(dptr1) 
      except: pass
      try:  dptr2 = int(dptr2) 
      except: pass
      if(type(dptr1) != type(dptr2) and dptr2 != ".") or (ptr2 == len(data)-1):
          if(ptr2 == len(data)-1) : ptr2 += 1
          row.append(data[ptr1 : ptr2])
          ptr1 = ptr2 
          if (len(row) == 4) :
              with open("./onelinefile.csv", "a", newline="") as csvfile:
                  write_obj = csv.writer(csvfile)
                  write_obj.writerow(row)
              row = []
          
textdata = readtxt("./onelinefile.txt")
convertcsv(textdata)
data = pd.read_csv("onelinefile.csv")
data.reset_index(drop=True, inplace=True)
data.head(10)
# Out:
#    1  Aaa    3.5      Maths
# 0  2  Bbb  4.200    Physics
# 1  3  Ccc  7.620  Chemistry
# 2  4  Ddd  9.550    Biology
# 3  5  Eee  4.000     Social
# 4  6  Fff  7.600    English
# 5  7  Ggg  3.111      Maths
# 6  8  Hhh  9.990    Physics
# 7  9  Iii  1.230     Civics
# 8  1  Aaa  3.500      Maths
# 9  2  Bbb  4.200    Physics

# %% [markdown]
# <h2>Q2</h2>

# %%
import pandas as pd

data = pd.read_csv('Q2-Dataset.csv')
missing_values = ["NAN", "NA", "-", "Nil"]
print("Before replacing all the missing values....")
print("Total number of missing values: ",data.isnull().sum().sum())
data['LotFrontage'].fillna(50, inplace=True)
data['Alley'].fillna('Grvl', inplace=True)
data['BsmtQual'].fillna('TA', inplace=True)
data['BsmtCond'].fillna('Gd', inplace=True)
data['BsmtExposure'].fillna('No', inplace=True)
data['BsmtFinType1'].fillna(100, inplace=True)
data['BsmtFinType2'].fillna(1000, inplace=True)
print("\n\nAfter replacing all the missing values....")
print("Total number of missing values: ",data.isnull().sum().sum())
print("\n\n")
data.head(10)
# Out:
# Before replacing all the missing values....
# Total number of missing values:  122
#
#
# After replacing all the missing values....
# Total number of missing values:  0
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1   2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2   3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3   4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4   5          60       RL         84.0    14260   Pave  Grvl      IR1
# 5   6          50       RL         85.0    14115   Pave  Grvl      IR1
# 6   7          20       RL         75.0    10084   Pave  Grvl      Reg
# 7   8          60       RL         50.0    10382   Pave  Grvl      IR1
# 8   9          50       RM         51.0     6120   Pave  Grvl      Reg
# 9  10         190       RL         50.0     7420   Pave  Grvl      Reg
#
# ...

# %% [markdown]
# <h2>Q3</h2>

# %%
import re

file = open("about.txt","r")
content = file.read()
print("The words that are atleast 6 letters in the given file are...")
#this finds all the elements with atleast 6 letters using regex
print(re.findall(r"\b\w{6,}\b",content))
file.close()

file = open("about.txt","r")
frequent_word = ""
frequency = 0
words = []
for line in file:
    line_word = line.lower().replace(',','').replace('.','').split(" ")
    for w in line_word:
        words.append(w)
for i in range(0, len(words)):
    count = 1
    for j in range(i+1, len(words)):
        if(words[i] == words[j]):
            count = count + 1
    if(count > frequency):
        frequency = count
        frequent_word = words[i]
print("\n\nMost repeated word: " + frequent_word)
print("Frequency: " + str(frequency))
file.close()
# Out:
# The words that are atleast 6 letters in the given file are...
# ['Python', 'almost', 'aspect', 'scientific', 'computing', 'America', 'Python', 'crunch', 'financial', 'Facebook', 'Python', 'library', 'Pandas', 'analysis', 'libraries', 'available', 'perform', 'analysis', 'Python', 'Pandas', 'Matplotlib']
#
#
# Most repeated word: python
# Frequency: 4

# %% [markdown]
# <h2>Q4</h2>

# %%
import pandas as pd

data = pd.read_csv("Q4-Dataset.csv")
arr = data.to_numpy()
arr = arr[arr[:, 2].argsort()]
sorted_data = pd.DataFrame(arr, columns=['ProductID', 'Price', 'Rating'])
sorted_data.head(20)
# Out:
#      ProductID Price Rating
# 0   B005P0HHGK   170    0.1
# 1   B000JEHAHS   133   0.12
# 2   B0001PB9FY   183   0.19
# 3   B005DUM9UQ   138   0.24
# 4   B002GWHC0G   165   0.26
# 5   B0001PB9FE   148   0.29
# 6   B0093NIWVO   127   0.31
# 7   B000G6RPMY   111   0.38
# 8   B0017I8UME   139   0.43
# 9   B0019CW0HE   178   0.43
# 10  B0017129DC   159   0.45
# 11  B000E7L2R4   148   0.48
# 12  B003SO503C   162    0.6
# 13  B001GVISJM   177   0.61
# 14  B001EO5ZME   156   0.64
# 15  B0064KO0BU   157   0.74
# 16  B001KUUNP6   178   0.74
# 17  B0025WIAN0    82   0.77
# 18  B000GGKQSO   185   0.83
# 19  B000ITVLE2   126   0.84

# %% [markdown]
# <h2>Q5</h2>

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("Q5.csv")
df = pd.DataFrame(data)
x = list(df.iloc[:, 0])
y = list(df.iloc[:, 1])
plt.plot(x, y, color='red')
plt.title("Price of houses vs their size")
plt.xlabel("Size")
plt.ylabel("Price")
plt.show()
plt.bar(x, y, color='red')
plt.title("Price of houses vs their size")
plt.xlabel("Size")
plt.ylabel("Price")
plt.show()
