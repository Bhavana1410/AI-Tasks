# %% [markdown]
# # AI TASK-3
#
# <hr>
#
# ### BATTULA BHAVANA
# ### CH.EN.U4AIE21010

# %% [markdown]
# <h2>Q2</h2>
# <h3>A</h3>

# %%
import numpy as np
import random

np.random.seed(100)
a = np.random.uniform(1,50, 20)
b = np.clip(a, a_min=15, a_max=45)
b = np.round_(b,3)
print("Replacing all the values that are greater than 45 to 45 and less than 15 to 15 using np.clip function")
print(b)
c = np.where(a>15, a, 15)
c = np.where(c<45, c, 45)
c = np.round_(c,3)
print("\n\nReplacing all the values that are greater than 45 to 45 and less than 15 to 15 using np.where function")
print(c)
# Out:
# Replacing all the values that are greater than 45 to 45 and less than 15 to 15 using np.clip function
# [27.627 15.    21.801 42.394 15.    15.    33.867 41.467 15.    29.18
#  44.675 15.    15.    15.    15.    45.    40.772 15.    40.995 15.   ]
#
#
# Replacing all the values that are greater than 45 to 45 and less than 15 to 15 using np.where function
# [27.627 15.    21.801 42.394 15.    15.    33.867 41.467 15.    29.18
#  44.675 15.    15.    15.    15.    45.    40.772 15.    40.995 15.   ]

# %% [markdown]
# <h3>B</h3>

# %%
import pandas as pd

df = pd.DataFrame({'STD':['33','44','40','80'], 'CityState':["Mumbai Maharashtra","Chennai Tamilnadu","Vishakapatnam Telangana","Bangalore Karnataka"]})
print(df)
df[['City','State']] = df.CityState.str.split(expand=True)
df.pop('CityState')
print("\n\nDataframe after spliting a text column into two separate columns")
print(df)
# Out:
#   STD                CityState
# 0  33       Mumbai Maharashtra
# 1  44        Chennai Tamilnadu
# 2  40  Vishakapatnam Telangana
# 3  80      Bangalore Karnataka
#
#
# Dataframe after spliting a text column into two separate columns
#   STD           City        State
# 0  33         Mumbai  Maharashtra
# 1  44        Chennai    Tamilnadu
# 2  40  Vishakapatnam    Telangana
# 3  80      Bangalore    Karnataka

# %% [markdown]
# <h2>Q3</h2>

# %%
import pandas as pd

df = pd.read_csv('./Q3.csv')
df.info() #displaying some basic info of the dataset

df.drop(['ID','DOB','10board','12board','Degree','CollegeID','12graduation','CollegeCityID','CollegeState','ComputerScience', 'MechanicalEngg', 'ElectricalEngg', 'TelecomEngg',
       'CivilEngg', 'ElectronicsAndSemicon', 'conscientiousness','Specialization','agreeableness','CollegeCityTier','GraduationYear','extraversion', 'Domain',
       'nueroticism'], axis = 1, inplace = True)
# dropping the values that are not needed to be processed to predict the salary
# and i have taken only computer programming as a skill for the engineer to be selected

df['Gender'] = df['Gender'].replace({'m': 0,'f': 1})
# replacing gender values such that it will remain as a integer (M=0, F=1)

# Now the data has been processed and ready to be used
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     2998 non-null   int64
#  1   Gender                 2998 non-null   object
#  2   DOB                    2998 non-null   object
#  3   10percentage           2998 non-null   float64
#  4   10board                2998 non-null   object
#  5   12graduation           2998 non-null   int64
#  6   12percentage           2998 non-null   float64
#  7   12board                2998 non-null   object
#  8   CollegeID              2998 non-null   int64
#  9   CollegeTier            2998 non-null   int64
#  10  Degree                 2998 non-null   object
#  11  Specialization         2998 non-null   object
#  12  collegeGPA             2998 non-null   float64
#  13  CollegeCityID          2998 non-null   int64
# ...

# %% [markdown]
# <h2>Q4</h2>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score

def slope():
  num = 0
  den = 0
  for i in range(n):
    num += (x[i] - xmean) * (y[i] - ymean)
    den += (x[i] - xmean) ** 2
  global m
  m = num/den
  global c
  c = ymean - (m * xmean)
  print("\n\n")
  print(f'Slope = {m} \tIntercept = {c}')

df = pd.read_csv('.\Q4.csv')
print(df.head(10))

x = df[['bmi']].values
y = df[['charges']].values
n = len(x)
xmean = x.mean()
ymean = y.mean()
slope()
df.plot(kind='scatter',x='bmi',y='charges')
plt.plot(x, c+m*x, linewidth=2, color='black')
plt.scatter(x.mean(), y.mean(), color='Blue', s=50)
plt.show()

# Spliting the data for supervised training
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.35)


# Creating Linear Regression
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
plt.plot(x_test,predictions,label='Linear Regression',color='b')
plt.scatter(x_test, y_test,label='Actual test data',color='g',alpha=.7)
plt.show()

#  Printing the score of the Linear Regression
print("Score of the ML algo: ", r2_score(y_test,y_pred))
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692
#
#
#
# Slope = [393.8730308] 	Intercept = [1192.93720896]
# Score of the ML algo:  0.054799642529842374
