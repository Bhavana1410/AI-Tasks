# %% [markdown]
# <h2>Q1</h2>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("./Q1 Datasets/NESTLEIND.csv")
data
# Out:
#             Date     Symbol Series  Prev Close      Open     High       Low  \
# 0     2010-01-08  NESTLEIND     EQ     2512.95   2555.00   2575.0   2475.20
# 1     2010-01-11  NESTLEIND     EQ     2494.65   2401.00   2515.0   2400.00
# 2     2010-01-12  NESTLEIND     EQ     2498.95   2540.00   2540.0   2471.35
# 3     2010-01-13  NESTLEIND     EQ     2502.85   2502.85   2540.0   2480.00
# 4     2010-01-14  NESTLEIND     EQ     2489.35   2535.00   2595.0   2470.00
# ...          ...        ...    ...         ...       ...      ...       ...
# 2801  2021-04-26  NESTLEIND     EQ    16625.70  16799.05  16895.0  16663.65
# 2802  2021-04-27  NESTLEIND     EQ    16870.60  16899.00  16930.0  16750.00
# 2803  2021-04-28  NESTLEIND     EQ    16779.00  16775.00  16831.1  16611.00
# 2804  2021-04-29  NESTLEIND     EQ    16633.80  16679.00  16714.6  16480.00
# 2805  2021-04-30  NESTLEIND     EQ    16502.55  16500.00  16569.2  16255.00
#
# ...

# %%
#as there is a large number of data which is not suitable for visualisation, we are going to reduce the number of data in the dataset
data = data.truncate(after = 50)
data
# Out:
#           Date     Symbol Series  Prev Close     Open     High      Low  \
# 0   2010-01-08  NESTLEIND     EQ     2512.95  2555.00  2575.00  2475.20
# 1   2010-01-11  NESTLEIND     EQ     2494.65  2401.00  2515.00  2400.00
# 2   2010-01-12  NESTLEIND     EQ     2498.95  2540.00  2540.00  2471.35
# 3   2010-01-13  NESTLEIND     EQ     2502.85  2502.85  2540.00  2480.00
# 4   2010-01-14  NESTLEIND     EQ     2489.35  2535.00  2595.00  2470.00
# 5   2010-01-15  NESTLEIND     EQ     2568.20  2580.00  2580.00  2500.05
# 6   2010-01-18  NESTLEIND     EQ     2513.50  2574.00  2574.00  2514.00
# 7   2010-01-19  NESTLEIND     EQ     2536.15  2567.00  2570.00  2531.00
# 8   2010-01-20  NESTLEIND     EQ     2556.10  2550.00  2575.00  2540.00
# 9   2010-01-21  NESTLEIND     EQ     2542.50  2539.90  2569.00  2499.90
# 10  2010-01-22  NESTLEIND     EQ     2526.20  2500.00  2530.00  2478.00
# 11  2010-01-25  NESTLEIND     EQ     2529.00  2665.35  2665.35  2510.00
# ...

# %%
sns.barplot(x = data["Volume"], y = data["Date"])
plt.rcParams["figure.figsize"] = [7, 15]

# %%
sns.histplot(x = data["Low"], y = data["Date"])
# Out:
# <AxesSubplot:xlabel='Low', ylabel='Date'>

# %%
sns.scatterplot(x = data["High"], y = data["Date"] )
# Out:
# <AxesSubplot:xlabel='High', ylabel='Date'>

# %%
data.corr() 
plt.rcParams["figure.figsize"] = [9, 5]
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2>Q2</h2>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("./Q2 Datasets/usa_country_wise.csv")
data
# Out:
#              UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 0       84036061   US  USA    840  36061.0    New York       New York
# 1       84036061   US  USA    840  36061.0    New York       New York
# 2       84036061   US  USA    840  36061.0    New York       New York
# 3       84036061   US  USA    840  36061.0    New York       New York
# 4       84036061   US  USA    840  36061.0    New York       New York
# ...          ...  ...  ...    ...      ...         ...            ...
# 627915  84090049   US  USA    840  90049.0  Unassigned           Utah
# 627916  84090051   US  USA    840  90051.0  Unassigned       Virginia
# 627917  84090054   US  USA    840  90054.0  Unassigned  West Virginia
# 627918  84090055   US  USA    840  90055.0  Unassigned      Wisconsin
# 627919  84090056   US  USA    840  90056.0  Unassigned        Wyoming
#
#        Country_Region        Lat      Long_                   Combined_Key  \
# ...

# %%
data = data.truncate(after=50)
data
# Out:
#          UID iso2 iso3  code3     FIPS    Admin2 Province_State  \
# 0   84036061   US  USA    840  36061.0  New York       New York
# 1   84036061   US  USA    840  36061.0  New York       New York
# 2   84036061   US  USA    840  36061.0  New York       New York
# 3   84036061   US  USA    840  36061.0  New York       New York
# 4   84036061   US  USA    840  36061.0  New York       New York
# 5   84036061   US  USA    840  36061.0  New York       New York
# 6   84036061   US  USA    840  36061.0  New York       New York
# 7   84036061   US  USA    840  36061.0  New York       New York
# 8   84036061   US  USA    840  36061.0  New York       New York
# 9   84036061   US  USA    840  36061.0  New York       New York
# 10  84036061   US  USA    840  36061.0  New York       New York
# 11  84036061   US  USA    840  36061.0  New York       New York
# 12  84036061   US  USA    840  36061.0  New York       New York
# 13  84036061   US  USA    840  36061.0  New York       New York
# ...

# %%
plt.rcParams["figure.figsize"] = [7, 15]
sns.histplot(x = data["Confirmed"], y = data["Date"])
#This plots the confirmed cases in newyork over different dates (histogram)
# Out:
# <AxesSubplot:xlabel='Confirmed', ylabel='Date'>

# %%
plt.rcParams["figure.figsize"] = [7, 15]
sns.histplot(y = data["Date"] , x = data["Deaths"] )
#This plots the deaths in newyork over different dates (histogram)
# Out:
# <AxesSubplot:xlabel='Deaths', ylabel='Date'>

# %%
sns.scatterplot(x = data["Confirmed"] ,y = data["Date"])
#This plots the confirmed cases in newyork over different dates (scatterplot)
# Out:
# <AxesSubplot:xlabel='Confirmed', ylabel='Date'>

# %%
sns.scatterplot(x = data["Deaths"], y = data["Date"] )
#This plots the deaths in newyork over different dates (scatterplot)
# Out:
# <AxesSubplot:xlabel='Deaths', ylabel='Date'>

# %% [markdown]
# <h2>Q3</h2>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = []
y = []
z = []
add = []
for i in range(0,20):
    x.append(i)
    a=np.cos(i) 
    #f(x) = cosx
    y.append(a)
    b=np.sin(i)
    b=-b
    #f'(x) = -sinx (derivative of cosx)
    z.append(b)
    c= a+b
    #result = sum of those two functions
    add.append(c)

plt.rcParams["figure.figsize"] = [5, 5]
plt.plot(x,y)
plt.title("f(x) = cosx", fontsize = 20)
plt.xlabel("Values in radians")
plt.ylabel("Value of the function")
plt.show()
plt.plot(x,z)
plt.title("f'(x) = -sinx", fontsize = 20)
plt.xlabel("Values in radians")
plt.ylabel("Value of the function")
plt.show()
plt.plot(x,add)
plt.title("f(x)+f'(x) = cosx-sinx", fontsize = 20)
plt.xlabel("Values in radians")
plt.ylabel("Value of the function")
plt.show()

# %% [markdown]
# <h2>Q4</h2>

# %%
list1 = [ 2, 3, 4, 5, 6, 7, 8, 9]
list2 = [ 4, 9, 16, 25, 36, 49, 64, 81]
print(set(zip(list1,list2)))
# Out:
# {(7, 49), (2, 4), (4, 16), (8, 64), (6, 36), (3, 9), (5, 25), (9, 81)}
